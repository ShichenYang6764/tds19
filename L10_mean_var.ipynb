# %%
import numpy as np
a=np.random.rand(100000)


import time
time_start=time.time()
def func(listTemp, n):
    for i in range(0, len(a), n):
        yield a[i:i + n]


temp = func(a, 10000)

b=[]
for i in temp:
        b.append(i.mean())
              
print(sum(b)/10)
time_end=time.time()
print('time is',time_end-time_start,'s')
# Out:
# 0.500731713743229
# time is 0.0020046234130859375 s

# %%
import time
time_start=time.time()
print(a.mean())
time_end=time.time()
print('time is',time_end-time_start,'s')
# Out:
# 0.500731713743229
# time is 0.0005006790161132812 s

# %%
import numpy

# %%
import time
time_start=time.time()
narray=numpy.array(a)
N=len(a)
sum1=narray.sum()
narray2=narray*narray
sum2=narray2.sum()
mean=sum1/N
var=sum2/N-mean**2
print(var)
time_end=time.time()
print('time is',time_end-time_start,'s')
# Out:
# 0.0836913016419975
# time is 0.006014108657836914 s

# %%
import time
time_start=time.time()
temp = func(a, 10000)
b=[]
for i in temp:
    narray=numpy.array(i)
    N=len(i)
    sum1=narray.sum()
    narray2=narray*narray
    sum2=narray2.sum()
    mean=sum1/N
    var=sum2/N-mean**2
    b.append(var)
print(sum(b)/10)
time_end=time.time()
print('time is',time_end-time_start,'s')
# Out:
# 0.08368672511343453
# time is 0.006016731262207031 s
